# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('telecom_churn.csv')
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
df.shape
# Out:
# (3333, 20)

# %%
df.shape[0]
# Out:
# 3333

# %%
df.shape[1]
# Out:
# 20

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3333, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
df.dtypes
# Out:
# State                      object
# Account length              int64
# Area code                   int64
# International plan         object
# Voice mail plan            object
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls             int64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls             int64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls           int64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls      int64
# Churn                        bool
# dtype: object

# %%
df['Churn'] = df['Churn'].astype('int64')

# %%
df['Churn'].dtypes
# Out:
# dtype('int64')

# %%
df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
df.describe(include=['object','bool'])
# Out:
#        State International plan Voice mail plan
# count   3333               3333            3333
# unique    51                  2               2
# top       WV                 No              No
# freq     106               3010            2411

# %%
df['Churn'].value_counts()
# Out:
# 0    2850
# 1     483
# Name: Churn, dtype: int64

# %%
df['Area code'].value_counts()
# Out:
# 415    1655
# 510     840
# 408     838
# Name: Area code, dtype: int64

# %%
df["Churn"].value_counts(normalize=True)
# Out:
# 0    0.855086
# 1    0.144914
# Name: Churn, dtype: float64

# %%
df['Area code'].value_counts(normalize=True)
# Out:
# 415    0.496550
# 510    0.252025
# 408    0.251425
# Name: Area code, dtype: float64

# %% [markdown]
# # sorting

# %%
df.sort_values(by='Total day charge', ascending=False).head()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 365     CO             154        415                 No              No
# 985     NY              64        415                Yes              No
# 2594    OH             115        510                Yes              No
# 156     OH              83        415                 No              No
# 605     MO             112        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 365                       0              350.8               75
# 985                       0              346.8               55
# 2594                      0              345.3               81
# 156                       0              337.4              120
# 605                       0              335.5               77
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
df.sort_values(by='Total day charge', ascending=True).head()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 1345    SD              98        415                 No              No
# 1397    VT             101        510                 No              No
# 2736    OK             127        510                 No             Yes
# 2753    OH             134        415                 No              No
# 1986    WI              70        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 1345                      0                0.0                0
# 1397                      0                0.0                0
# 2736                     27                2.6              113
# 2753                      0                7.8               86
# 1986                      0                7.9              100
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
df.sort_values(by=['Churn','Total day charge'],
              ascending=[True,False]).head()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 688     MN              13        510                 No             Yes
# 2259    NC             210        415                 No             Yes
# 534     LA              67        510                 No              No
# 575     SD             114        415                 No             Yes
# 2858    AL             141        510                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 688                      21              315.6              105
# 2259                     31              313.8               87
# 534                       0              310.4               97
# 575                      36              309.9               90
# 2858                     28              308.0              123
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
df.sort_values(by=['Total day charge','Total day calls'],
              ascending=[True,False]).head()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 1345    SD              98        415                 No              No
# 1397    VT             101        510                 No              No
# 2736    OK             127        510                 No             Yes
# 2753    OH             134        415                 No              No
# 1986    WI              70        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 1345                      0                0.0                0
# 1397                      0                0.0                0
# 2736                     27                2.6              113
# 2753                      0                7.8               86
# 1986                      0                7.9              100
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
df["Churn"].mean()
# Out:
# 0.14491449144914492

# %%
df["Account length"].mean()
# Out:
# 101.06480648064806

# %%
df[df['Churn'] == 1].mean()
# Out:
# Account length            102.664596
# Area code                 437.817805
# Number vmail messages       5.115942
# Total day minutes         206.914079
# Total day calls           101.335404
# Total day charge           35.175921
# Total eve minutes         212.410145
# Total eve calls           100.561077
# Total eve charge           18.054969
# Total night minutes       205.231677
# Total night calls         100.399586
# Total night charge          9.235528
# Total intl minutes         10.700000
# Total intl calls            4.163561
# Total intl charge           2.889545
# Customer service calls      2.229814
# Churn                       1.000000
# dtype: float64

# %%
df[df["Account length"]==4].mean()
# Out:
# Account length              4.00
# Area code                 510.00
# Number vmail messages       0.00
# Total day minutes         145.30
# Total day calls            89.00
# Total day charge           24.70
# Total eve minutes         303.80
# Total eve calls            93.00
# Total eve charge           25.82
# Total night minutes       206.10
# Total night calls          82.00
# Total night charge          9.27
# Total intl minutes          8.90
# Total intl calls            4.00
# Total intl charge           2.40
# Customer service calls      0.00
# Churn                       0.00
# dtype: float64

# %%
#How much time (on average) do churned users spend on the phone during daytime?
df[df["Churn"]==1]['Total day minutes'].mean()
# Out:
# 206.91407867494814

# %%
df[df['State']=='OH']['Total day minutes'].mean()
# Out:
# 183.27435897435893

# %%
df['Total day minutes'].mean()
# Out:
# 179.77509750975116

# %%
# What is the maximum length of international calls among loyal users (Churn == 0) who do not have an international plan?
df[(df['Churn'] == 0) & (df['International plan'] == 'No')]['Total intl minutes'].max()
# Out:
# 18.9

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
df[(df["State"] == 'NJ') & (df['International plan'] == 'No')]['Total intl minutes'].max()
# Out:
# 15.7

# %%
df["Total intl minutes"].min()
# Out:
# 0.0

# %%
df[(df["State"] == 'NJ') & (df['International plan'] == 'No')]['Total intl minutes'].min()
# Out:
# 5.8

# %%
df.loc[0:5,'State':'Area code']
# Out:
#   State  Account length  Area code
# 0    KS             128        415
# 1    OH             107        415
# 2    NJ             137        415
# 3    OH              84        408
# 4    OK              75        415
# 5    AL             118        510

# %%
df.iloc[0:5,0:3]
# Out:
#   State  Account length  Area code
# 0    KS             128        415
# 1    OH             107        415
# 2    NJ             137        415
# 3    OH              84        408
# 4    OK              75        415

# %%
df.apply(np.max)
# Out:
# State                        WY
# Account length              243
# Area code                   510
# International plan          Yes
# Voice mail plan             Yes
# Number vmail messages        51
# Total day minutes         350.8
# Total day calls             165
# Total day charge          59.64
# Total eve minutes         363.7
# Total eve calls             170
# Total eve charge          30.91
# Total night minutes         395
# Total night calls           175
# Total night charge        17.77
# Total intl minutes           20
# Total intl calls             20
# Total intl charge           5.4
# Customer service calls        9
# Churn                         1
# dtype: object

# %%
df.apply(np.min)
# Out:
# State                       AK
# Account length               1
# Area code                  408
# International plan          No
# Voice mail plan             No
# Number vmail messages        0
# Total day minutes            0
# Total day calls              0
# Total day charge             0
# Total eve minutes            0
# Total eve calls              0
# Total eve charge             0
# Total night minutes       23.2
# Total night calls           33
# Total night charge        1.04
# Total intl minutes           0
# Total intl calls             0
# Total intl charge            0
# Customer service calls       0
# Churn                        0
# dtype: object

# %%
df[df['State'].apply(lambda state: state[0] == 'W')].head()
# Out:
#    State  Account length  Area code International plan Voice mail plan  \
# 9     WV             141        415                Yes             Yes
# 26    WY              57        408                 No             Yes
# 44    WI              64        510                 No              No
# 49    WY              97        415                 No             Yes
# 54    WY              87        415                 No              No
#
#     Number vmail messages  Total day minutes  Total day calls  \
# 9                      37              258.6               84
# 26                     39              213.0              115
# 44                      0              154.0               67
# 49                     24              133.2              135
# 54                      0              151.0               83
#
#     Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 9              43.96              222.0              111             18.87
# ...

# %%
d = {'No':False,'Yes':True}
df["International plan"] = df['International plan'].map(d)
df.head()
# Out:
#   State  Account length  Area code  International plan Voice mail plan  \
# 0    KS             128        415               False             Yes
# 1    OH             107        415               False             Yes
# 2    NJ             137        415               False              No
# 3    OH              84        408                True              No
# 4    OK              75        415                True              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
df.replace({'Voice mail plan':d}).head()
# Out:
#   State  Account length  Area code  International plan  Voice mail plan  \
# 0    KS             128        415               False             True
# 1    OH             107        415               False             True
# 2    NJ             137        415               False            False
# 3    OH              84        408                True            False
# 4    OK              75        415                True            False
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
columns_to_show = ['Total day minutes', 'Total eve minutes', 
                   'Total night minutes']
columns_to_show
# Out:
# ['Total day minutes', 'Total eve minutes', 'Total night minutes']

# %%
df.groupby(["Churn"])[columns_to_show].describe(percentiles=[])
# Out:
#       Total day minutes                                            \
#                   count        mean        std  min    50%    max
# Churn
# 0                2850.0  175.175754  50.181655  0.0  177.2  315.6
# 1                 483.0  206.914079  68.997792  0.0  217.6  350.8
#
#       Total eve minutes                                             \
#                   count        mean        std   min    50%    max
# Churn
# 0                2850.0  199.043298  50.292175   0.0  199.6  361.8
# 1                 483.0  212.410145  51.728910  70.9  211.3  363.7
#
#       Total night minutes
#                     count        mean        std   min     50%    max
# Churn
# 0                  2850.0  200.133193  51.105032  23.2  200.25  395.0
# 1                   483.0  205.231677  47.132825  47.4  204.80  354.9

# %%
columns_to_show = ['Total day minutes', 'Total eve minutes', 
                   'Total night minutes']
columns_to_show
# Out:
# ['Total day minutes', 'Total eve minutes', 'Total night minutes']

# %%
df.groupby(['Churn'])[columns_to_show].agg([np.mean,np.std,np.min,np.max])
# Out:
#       Total day minutes                        Total eve minutes             \
#                    mean        std amin   amax              mean        std
# Churn
# 0            175.175754  50.181655  0.0  315.6        199.043298  50.292175
# 1            206.914079  68.997792  0.0  350.8        212.410145  51.728910
#
#                    Total night minutes
#        amin   amax                mean        std  amin   amax
# Churn
# 0       0.0  361.8          200.133193  51.105032  23.2  395.0
# 1      70.9  363.7          205.231677  47.132825  47.4  354.9

# %%
pd.crosstab(df["Churn"], df["International plan"])
# Out:
# International plan  False  True
# Churn
# 0                    2664    186
# 1                     346    137

# %%
df.head()
# Out:
#   State  Account length  Area code  International plan Voice mail plan  \
# 0    KS             128        415               False             Yes
# 1    OH             107        415               False             Yes
# 2    NJ             137        415               False              No
# 3    OH              84        408                True              No
# 4    OK              75        415                True              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
pd.crosstab(df['State'],df["International plan"]).head()
# Out:
# International plan  False  True
# State
# AK                     48      4
# AL                     72      8
# AR                     47      8
# AZ                     61      3
# CA                     30      4

# %%
pd.crosstab(df['Churn'],df["Voice mail plan"], normalize=True)
# Out:
# Voice mail plan        No       Yes
# Churn
# 0                0.602460  0.252625
# 1                0.120912  0.024002

# %%
df.pivot_table(['Total day calls', 'Total eve calls', 'Total night calls'],['Area code'], aggfunc='mean')
# Out:
#            Total day calls  Total eve calls  Total night calls
# Area code
# 408             100.496420        99.788783          99.039379
# 415             100.576435       100.503927         100.398187
# 510             100.097619        99.671429         100.601190

# %%
total_calls = df['Total day calls'] + df['Total eve calls'] + \
              df['Total night calls'] + df['Total intl calls']
df['total call'] = total_calls
#==>second method to create a column and add the value(
#df.insert(loc=len(df.columns), column='Total calls', value=total_calls) 

df.head()
# Out:
#   State  Account length  Area code  International plan Voice mail plan  \
# 0    KS             128        415               False             Yes
# 1    OH             107        415               False             Yes
# 2    NJ             137        415               False              No
# 3    OH              84        408                True              No
# 4    OK              75        415                True              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  ...  Total night minutes  \
# 0             45.07              197.4  ...                244.7
# ...

# %%
df.drop(['Total day charge','total call'], axis=1, inplace=True)

# %%
df.head()
# Out:
#   State  Account length  Area code  International plan Voice mail plan  \
# 0    KS             128        415               False             Yes
# 1    OH             107        415               False             Yes
# 2    NJ             137        415               False              No
# 3    OH              84        408                True              No
# 4    OK              75        415                True              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total eve minutes  Total eve calls  Total eve charge  Total night minutes  \
# 0              197.4               99             16.78                244.7
# ...

# %%
# remove th rows in data sets
df.drop([1,2]).head()
# Out:
#   State  Account length  Area code  International plan Voice mail plan  \
# 0    KS             128        415               False             Yes
# 3    OH              84        408                True              No
# 4    OK              75        415                True              No
# 5    AL             118        510                True              No
# 6    MA             121        510               False             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 3                      0              299.4               71
# 4                      0              166.7              113
# 5                      0              223.4               98
# 6                     24              218.2               88
#
#    Total eve minutes  Total eve calls  Total eve charge  Total night minutes  \
# 0              197.4               99             16.78                244.7
# ...

# %% [markdown]
# # 2. First attempt at predicting telecom churn

# %%
pd.crosstab(df["Churn"], df['International plan'], margins=True)
# Out:
# International plan  False  True   All
# Churn
# 0                    2664   186  2850
# 1                     346   137   483
# All                  3010   323  3333

# %%
import matplotlib.pyplot as plt
# pip install seaborn 
import seaborn as sns
# Graphics in retina format are more sharp and legible
# %config InlineBackend.figure_format = 'retina'

# %%
sns.countplot(x='International plan', hue='Churn', data=df);

# %%
sns.countplot(x='International plan', hue='State', data=df);

# %%
df['Many_service_calls'] = (df['Customer service calls'] > 3).astype('int')

pd.crosstab(df['Many_service_calls'], df['Churn'], margins=True)
# Out:
# Churn                  0    1   All
# Many_service_calls
# 0                   2721  345  3066
# 1                    129  138   267
# All                 2850  483  3333

# %%
sns.countplot(x='Many_service_calls', hue='Churn', data=df);
